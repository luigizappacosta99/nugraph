# %% [markdown]
# ### Set autoreloading
# This extension will automatically update with any changes to packages in real time

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Import packages
# We'll need the `pynuml` and `nugraph` packages

# %%
import pynuml
import nugraph as ng
# Out:
# /sps/lbno/zappacosta/miniconda3/envs/numl/lib/python3.13/site-packages/cupy/_environment.py:596: UserWarning:
#
#
# --------------------------------------------------------------------------------
#
#   CuPy may not function correctly because multiple CuPy packages are installed
#   in your environment:
#
#     cupy, cupy-cuda12x
#
#   Follow these steps to resolve this issue:
#
#     1. For all packages listed above, run the following command to remove all
#        existing CuPy installations:
#
#          $ pip uninstall <package_name>
#
#       If you previously installed CuPy via conda, also run the following:
#
#          $ conda uninstall cupy
#
#     2. Install the appropriate CuPy package.
#        Refer to the Installation Guide for detailed instructions.
#
#          https://docs.cupy.dev/en/stable/install.html
#
# --------------------------------------------------------------------------------

# %% [markdown]
# ### Open HDF5 event file
#
# This file contains the low-level tables we need to process into graph objects

# %%
file = pynuml.io.File("/sps/lbno/zappacosta/v10_11/nugraph/pynuml/tests/uboone-opendata.test.h5")
# Out:
# Loading /sps/lbno/zappacosta/v10_11/nugraph/pynuml/tests/uboone-opendata.test.h5...

# %% [markdown]
# ### Create hit graph producer
#
# Create a class that can read input information and use it to generate graphs

# %%
semantic_labeller = pynuml.labels.StandardLabels()
event_labeller = pynuml.labels.FlavorLabels()
processor = pynuml.process.HitGraphProducer(
        file=file,
        semantic_labeller=semantic_labeller,
        event_labeller=event_labeller,
        label_vertex=True,
        label_position=False)

# %% [markdown]
# ## Configure plotting utility
# Instantiate the **pynuml** utility for plotting graph objects, which will allow us to visualise the graphs we create

# %%
plot = pynuml.plot.GraphPlot(
    planes=('u', 'v', 'y'),
    classes=semantic_labeller.labels[:-1])

# %% [markdown]
# ### Load a buffer of input graphs
#
# For interactive testing, we can use `read_data` to load the first 100 events in the event file using the following syntax, which will return a list of events that we can use to initialise an iterator

# %%
file.read_data(0, 100)
evts = file.build_evt(1,1)

# %% [markdown]
# ### Retrieve the next event
#
# This block retrieves an event from the buffer. Since we defined `evts` as an iterator over our 100 events, the following block can be executed multiple times, and each time it's executed, it will step to the next event in the buffer. After fetching an event, we pass it into the processor to create a graph. Not all events produce good graphs, so if the next event does not return a valid graph, the code will continue to fetch events until it finds the next event that produces a valid graph.

# %%
name, data = processor(evts[0])

# %% [markdown]
# ### Visualise graph
#
# We can use the plotting utility to take a closer look at the graph we just produced.

# %%
fig = plot.plot(data, target='instance', how='true', filter='show')
fig
# Out:
# FigureWidget({
#     'data': [{'customdata': array([['background', '-1'],
#                                    ['background', '-1'],
#                                    ['background', '-1'],
#                                    ['background', '-1'],
#                                    ['background', '-1'],
#                                    ['background', '-1'],
#                                    ['background', '-1'],
#                                    ['background', '-1'],
#                                    ['background', '-1'],
#                                    ['background', '-1'],
#                                    ['background', '-1'],
#                                    ['background', '-1'],
#                                    ['background', '-1']], dtype=object),
#               'hovertemplate': ('instance truth=%{customdata[1]' ... '>drift=%{y:.1f}<extra></extra>'),
#               'legendgroup': '-1, background',
#               'marker': {'color': '#FF97FF', 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': '-1, background',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '8d7bc704-02b5-40e9-83d4-afff024ae146',
#               'x': {'bdata': 'AJBVRQDAVEUAwE1FACBIRQDQP0UAgD5FAFA9RQAAPUUA8DtFAMAcRQAgBUUAEAJFAMD7RA==', 'dtype': 'f4'},
#               'xaxis': 'x',
#               'y': {'bdata': '5KM+RY3QRUWlG51FdvtURVYsw0Vr0INFGwhVRcqJh0Uxn1hFHgCsRQx5s0VllqxFdhO5RQ==', 'dtype': 'f4'},
#               'yaxis': 'y'},
#              {'customdata': array([['background', '-1'],
#                                    ['background', '-1'],
#                                    ['background', '-1'],
#                                    ['background', '-1'],
#                                    ['background', '-1'],
#                                    ['background', '-1'],
#                                    ['background', '-1'],
#                                    ['background', '-1'],
#                                    ['background', '-1'],
#                                    ['background', '-1'],
#                                    ['background', '-1'],
#                                    ['background', '-1'],
#                                    ['background', '-1'],
#                                    ['background', '-1'],
#                                    ['background', '-1']], dtype=object),
#               'hovertemplate': ('instance truth=%{customdata[1]' ... '>drift=%{y:.1f}<extra></extra>'),
#               'legendgroup': '-1, background',
#               'marker': {'color': '#FF97FF', 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': '-1, background',
#               'orientation': 'v',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'ed79847c-9345-44e9-9c73-7539e722def1',
#               'x': {'bdata': 'AADaRACg0EQAQL5EAICvRADgqkQAwKpEAMCqRACgqkQAIKpEACClRABgm0QA4JpEAMCaRACAkkQAIJJE',
#                     'dtype': 'f4'},
#               'xaxis': 'x2',
#               'y': {'bdata': '4CnDRe4jnUW7NI5Ffx20RcWHq0VjrbVFGZWART1lw0VG+J9FzHWhRSNShUWiS69FOTyvRTd6nkWUeKxF',
#                     'dtype': 'f4'},
#               'yaxis': 'y2'},
#              {'customdata': array([['background', '-1'],
#                                    ['background', '-1'],
#                                    ['background', '-1'],
#                                    ['background', '-1'],
#                                    ['background', '-1'],
#                                    ['background', '-1'],
#                                    ['background', '-1']], dtype=object),
#               'hovertemplate': ('instance truth=%{customdata[1]' ... '>drift=%{y:.1f}<extra></extra>'),
#               'legendgroup': '-1, background',
#               'marker': {'color': '#FF97FF', 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': '-1, background',
#               'orientation': 'v',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'e7459032-1f18-477e-b495-707df62b595e',
#               'x': {'bdata': 'AADQRABgyUQAQKdEACCnRAAAmUQAII9EAACPRA==', 'dtype': 'f4'},
#               'xaxis': 'x3',
#               'y': {'bdata': 'ohK5Ra//q0XBvZFFd8KRRc73mkWfcrFFj3uxRQ==', 'dtype': 'f4'},
#               'yaxis': 'y3'},
#              {'customdata': array([['diffuse', '-1'],
#                                    ['diffuse', '-1'],
#                                    ['diffuse', '-1'],
#                                    ['diffuse', '-1'],
#                                    ['diffuse', '-1'],
#                                    ['diffuse', '-1']], dtype=object),
#               'hovertemplate': ('instance truth=%{customdata[1]' ... '>drift=%{y:.1f}<extra></extra>'),
#               'legendgroup': '-1, diffuse',
#               'marker': {'color': '#FF97FF', 'symbol': 'square'},
#               'mode': 'markers',
#               'name': '-1, diffuse',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'bc7b97cf-87cb-41e9-a88e-8b5bfd589789',
#               'x': {'bdata': 'AAAPRQDwDkUAUA5FADANRQAADUUA8AxF', 'dtype': 'f4'},
#               'xaxis': 'x',
#               'y': {'bdata': '722YRaVqmEWcR6ZFMXaiRRIAoUU6DKFF', 'dtype': 'f4'},
#               'yaxis': 'y'},
#              {'customdata': array([['diffuse', '-1'],
#                                    ['diffuse', '-1'],
#                                    ['diffuse', '-1'],
#                                    ['diffuse', '-1'],
#                                    ['diffuse', '-1'],
#                                    ['diffuse', '-1'],
#                                    ['diffuse', '-1'],
#                                    ['diffuse', '-1'],
#                                    ['diffuse', '-1']], dtype=object),
#               'hovertemplate': ('instance truth=%{customdata[1]' ... '>drift=%{y:.1f}<extra></extra>'),
#               'legendgroup': '-1, diffuse',
#               'marker': {'color': '#FF97FF', 'symbol': 'square'},
#               'mode': 'markers',
#               'name': '-1, diffuse',
#               'orientation': 'v',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'c22ffe2f-fad5-420b-ae0b-1dfb9aa975b6',
#               'x': {'bdata': 'AMCzRACgs0QAgLNEAICtRABgrUQAAK1EAOCsRACgrEQAgKxE', 'dtype': 'f4'},
#               'xaxis': 'x2',
#               'y': {'bdata': '4mmYRQNtmEU2bphFpAyhRQwGoUWTTqZFAGCmRQd4okVdfaJF', 'dtype': 'f4'},
#               'yaxis': 'y2'},
#              {'customdata': array([['diffuse', '-1'],
#                                    ['diffuse', '-1'],
#                                    ['diffuse', '-1'],
#                                    ['diffuse', '-1'],
#                                    ['diffuse', '-1'],
#                                    ['diffuse', '-1'],
#                                    ['diffuse', '-1'],
#                                    ['diffuse', '-1']], dtype=object),
#               'hovertemplate': ('instance truth=%{customdata[1]' ... '>drift=%{y:.1f}<extra></extra>'),
#               'legendgroup': '-1, diffuse',
#               'marker': {'color': '#FF97FF', 'symbol': 'square'},
#               'mode': 'markers',
#               'name': '-1, diffuse',
#               'orientation': 'v',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'db26dad7-c673-47ed-b7b3-e42495716de2',
#               'x': {'bdata': 'AKDDRACAw0QAwMFEAKDBRACAwEQAYMBEAGC+RABAvkQ=', 'dtype': 'f4'},
#               'xaxis': 'x3',
#               'y': {'bdata': 'hU2mRa5CpkUJeaJFk3eiRdIPoUV6MqFFdnSYRfVvmEU=', 'dtype': 'f4'},
#               'yaxis': 'y3'},
#              {'customdata': array([['shower', '0'],
#                                    ['shower', '0'],
#                                    ['shower', '0'],
#                                    ['shower', '0'],
#                                    ['shower', '0'],
#                                    ['shower', '0'],
#                                    ['shower', '0'],
#                                    ['shower', '0'],
#                                    ['shower', '0'],
#                                    ['shower', '0'],
#                                    ['shower', '0'],
#                                    ['shower', '0'],
#                                    ['shower', '0'],
#                                    ['shower', '0'],
#                                    ['shower', '0'],
#                                    ['shower', '0'],
#                                    ['shower', '0'],
#                                    ['shower', '0'],
#                                    ['shower', '0'],
#                                    ['shower', '0'],
#                                    ['shower', '0'],
#                                    ['shower', '0'],
#                                    ['shower', '0'],
#                                    ['shower', '0'],
#                                    ['shower', '0'],
#                                    ['shower', '0'],
#                                    ['shower', '0'],
#                                    ['shower', '0'],
#                                    ['shower', '0'],
#                                    ['shower', '0'],
#                                    ['shower', '0']], dtype=object),
#               'hovertemplate': ('instance truth=%{customdata[1]' ... '>drift=%{y:.1f}<extra></extra>'),
#               'legendgroup': '0, shower',
#               'marker': {'color': '#FECB52', 'symbol': 'diamond'},
#               'mode': 'markers',
#               'name': '0, shower',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '7d6f284e-299a-42a7-a75b-e54da493b4ca',
#               'x': {'bdata': ('APAfRQDgH0UA4BpFANAaRQAwEEUAIB' ... 'UAQAtFADALRQAgC0UAEAtFAAALRQ=='),
#                     'dtype': 'f4'},
#               'xaxis': 'x',
#               'y': {'bdata': ('mDmmRXY2pkXJgapFhoOqRaduqUUae6' ... 'WoNqlFjiOpRaUTqUUo/6hFEO6oRQ=='),
#                     'dtype': 'f4'},
#               'yaxis': 'y'},
#              {'customdata': array([['shower', '0'],
#                                    ['shower', '0'],
#                                    ['shower', '0'],
#                                    ['shower', '0'],
#                                    ['shower', '0'],
#                                    ['shower', '0'],
#                                    ['shower', '0'],
#                                    ['shower', '0'],
#                                    ['shower', '0'],
#                                    ['shower', '0'],
#                                    ['shower', '0'],
#                                    ['shower', '0'],
#                                    ['shower', '0'],
#                                    ['shower', '0'],
#                                    ['shower', '0'],
#                                    ['shower', '0'],
#                                    ['shower', '0'],
#                                    ['shower', '0'],
#                                    ['shower', '0']], dtype=object),
#               'hovertemplate': ('instance truth=%{customdata[1]' ... '>drift=%{y:.1f}<extra></extra>'),
#               'legendgroup': '0, shower',
#               'marker': {'color': '#FECB52', 'symbol': 'diamond'},
#               'mode': 'markers',
#               'name': '0, shower',
#               'orientation': 'v',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'cbe79d65-2468-4bfb-81fd-dfca681613ea',
#               'x': {'bdata': ('AGDIRABAyEQAIL9EAAC/RABAt0QAQK' ... 'QAIK1EAACtRADgrEQAwKxEAKCsRA=='),
#                     'dtype': 'f4'},
#               'xaxis': 'x2',
#               'y': {'bdata': ('0zCmReA7pkVKhKpF6n6qRZ4NoEVtg6' ... 'VQg6lFsF6pRdlHqUW0IqlFAAWpRQ=='),
#                     'dtype': 'f4'},
#               'yaxis': 'y2'},
#              {'customdata': array([['shower', '0'],
#                                    ['shower', '0'],
#                                    ['shower', '0'],
#                                    ['shower', '0'],
#                                    ['shower', '0'],
#                                    ['shower', '0'],
#                                    ['shower', '0'],
#                                    ['shower', '0'],
#                                    ['shower', '0'],
#                                    ['shower', '0'],
#                                    ['shower', '0'],
#                                    ['shower', '0'],
#                                    ['shower', '0'],
#                                    ['shower', '0'],
#                                    ['shower', '0'],
#                                    ['shower', '0'],
#                                    ['shower', '0'],
#                                    ['shower', '0'],
#                                    ['shower', '0']], dtype=object),
#               'hovertemplate': ('instance truth=%{customdata[1]' ... '>drift=%{y:.1f}<extra></extra>'),
#               'legendgroup': '0, shower',
#               'marker': {'color': '#FECB52', 'symbol': 'diamond'},
#               'mode': 'markers',
#               'name': '0, shower',
#               'orientation': 'v',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '18c84caf-04b8-4fdc-94e4-81e80e07bbdf',
#               'x': {'bdata': ('AKDLRACAy0QAgMtEAGDLRABgy0QAQM' ... 'QAAL5EAOC9RADAvUQAoL1EAIC9RA=='),
#                     'dtype': 'f4'},
#               'xaxis': 'x3',
#               'y': {'bdata': ('1F+pRZE6pkVMcKlFETimReeLqUVMtK' ... 'VIoalFP4epRXpiqUVgPKlFDh6pRQ=='),
#                     'dtype': 'f4'},
#               'yaxis': 'y3'},
#              {'customdata': array([['hadron', '2'],
#                                    ['hadron', '2'],
#                                    ['hadron', '2'],
#                                    ['hadron', '2'],
#                                    ['hadron', '2'],
#                                    ['hadron', '2'],
#                                    ['hadron', '2'],
#                                    ['hadron', '2'],
#                                    ['hadron', '2'],
#                                    ['hadron', '2']], dtype=object),
#               'hovertemplate': ('instance truth=%{customdata[1]' ... '>drift=%{y:.1f}<extra></extra>'),
#               'legendgroup': '2, hadron',
#               'marker': {'color': '#636efa', 'symbol': 'x'},
#               'mode': 'markers',
#               'name': '2, hadron',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '98df17e8-421d-4518-a518-fd5be766f0e6',
#               'x': {'bdata': 'AKANRQCQDUUAgA1FAHANRQBgDUUAUA1FAEANRQAwDUUAIA1FABANRQ==', 'dtype': 'f4'},
#               'xaxis': 'x',
#               'y': {'bdata': 'PU6gRedSoEWKYaBFmXagRWOMoEVOn6BFwbKgRTPGoEVR2aBFoO2gRQ==', 'dtype': 'f4'},
#               'yaxis': 'y'},
#              {'customdata': array([['hadron', '2'],
#                                    ['hadron', '2'],
#                                    ['hadron', '2'],
#                                    ['hadron', '2'],
#                                    ['hadron', '2']], dtype=object),
#               'hovertemplate': ('instance truth=%{customdata[1]' ... '>drift=%{y:.1f}<extra></extra>'),
#               'legendgroup': '2, hadron',
#               'marker': {'color': '#636efa', 'symbol': 'x'},
#               'mode': 'markers',
#               'name': '2, hadron',
#               'orientation': 'v',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '5d5166e5-7b33-40ff-96e0-5bacbf821e95',
#               'x': {'bdata': 'AECtRAAgrUQAAK1EAOCsRADArEQ=', 'dtype': 'f4'},
#               'xaxis': 'x2',
#               'y': {'bdata': 'D/GgRSKxoEW4eqBFLmCgRYNaoEU=', 'dtype': 'f4'},
#               'yaxis': 'y2'},
#              {'customdata': array([['hadron', '2'],
#                                    ['hadron', '2'],
#                                    ['hadron', '2'],
#                                    ['hadron', '2'],
#                                    ['hadron', '2'],
#                                    ['hadron', '2'],
#                                    ['hadron', '2'],
#                                    ['hadron', '2'],
#                                    ['hadron', '2'],
#                                    ['hadron', '2'],
#                                    ['hadron', '2'],
#                                    ['hadron', '2'],
#                                    ['hadron', '2'],
#                                    ['hadron', '2']], dtype=object),
#               'hovertemplate': ('instance truth=%{customdata[1]' ... '>drift=%{y:.1f}<extra></extra>'),
#               'legendgroup': '2, hadron',
#               'marker': {'color': '#636efa', 'symbol': 'x'},
#               'mode': 'markers',
#               'name': '2, hadron',
#               'orientation': 'v',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '6d1da938-678b-4054-bb0e-ca9c4d56214f',
#               'x': {'bdata': 'AEDCRAAgwkQAAMJEAODBRADAwUQAoMFEAIDBRABgwUQAQMFEACDBRAAAwUQA4MBEAMDARACgwEQ=',
#                     'dtype': 'f4'},
#               'xaxis': 'x3',
#               'y': {'bdata': 'Vk6gRVBRoEWyXKBFuW6gRUeAoEXjkKBFrZ+gRZOtoEV+u6BFmcqgRWXZoEUw5qBFG/SgRbABoUU=',
#                     'dtype': 'f4'},
#               'yaxis': 'y3'},
#              {'customdata': array([['hadron', '1'],
#                                    ['hadron', '1'],
#                                    ['hadron', '1'],
#                                    ['hadron', '1'],
#                                    ['hadron', '1'],
#                                    ['hadron', '1'],
#                                    ['hadron', '1'],
#                                    ['hadron', '1'],
#                                    ['hadron', '1'],
#                                    ['hadron', '1'],
#                                    ['hadron', '1'],
#                                    ['hadron', '1'],
#                                    ['hadron', '1'],
#                                    ['hadron', '1'],
#                                    ['hadron', '1'],
#                                    ['hadron', '1'],
#                                    ['hadron', '1'],
#                                    ['hadron', '1'],
#                                    ['hadron', '1'],
#                                    ['hadron', '1'],
#                                    ['hadron', '1'],
#                                    ['hadron', '1'],
#                                    ['hadron', '1'],
#                                    ['hadron', '1'],
#                                    ['hadron', '1'],
#                                    ['hadron', '1'],
#                                    ['hadron', '1'],
#                                    ['hadron', '1'],
#                                    ['hadron', '1'],
#                                    ['hadron', '1'],
#                                    ['hadron', '1']], dtype=object),
#               'hovertemplate': ('instance truth=%{customdata[1]' ... '>drift=%{y:.1f}<extra></extra>'),
#               'legendgroup': '1, hadron',
#               'marker': {'color': '#EF553B', 'symbol': 'x'},
#               'mode': 'markers',
#               'name': '1, hadron',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '02e9ea42-7761-4db5-bae3-b189215e7486',
#               'x': {'bdata': ('AOAMRQDQDEUAwAxFALAMRQCgDEUAkA' ... 'UAMAtFACALRQAQC0UAAAtFAPAKRQ=='),
#                     'dtype': 'f4'},
#               'xaxis': 'x',
#               'y': {'bdata': ('xzOhRRJ7oUX9tKFFFPChRYIrokU+Z6' ... 'WizqdF7xOoRR9TqEUJoahFVsaoRQ=='),
#                     'dtype': 'f4'},
#               'yaxis': 'y'},
#              {'customdata': array([['hadron', '1'],
#                                    ['hadron', '1'],
#                                    ['hadron', '1'],
#                                    ['hadron', '1'],
#                                    ['hadron', '1'],
#                                    ['hadron', '1'],
#                                    ['hadron', '1'],
#                                    ['hadron', '1'],
#                                    ['hadron', '1'],
#                                    ['hadron', '1'],
#                                    ['hadron', '1'],
#                                    ['hadron', '1'],
#                                    ['hadron', '1'],
#                                    ['hadron', '1'],
#                                    ['hadron', '1'],
#                                    ['hadron', '1'],
#                                    ['hadron', '1'],
#                                    ['hadron', '1'],
#                                    ['hadron', '1'],
#                                    ['hadron', '1'],
#                                    ['hadron', '1'],
#                                    ['hadron', '1'],
#                                    ['hadron', '1'],
#                                    ['hadron', '1'],
#                                    ['hadron', '1'],
#                                    ['hadron', '1'],
#                                    ['hadron', '1'],
#                                    ['hadron', '1'],
#                                    ['hadron', '1'],
#                                    ['hadron', '1'],
#                                    ['hadron', '1'],
#                                    ['hadron', '1']], dtype=object),
#               'hovertemplate': ('instance truth=%{customdata[1]' ... '>drift=%{y:.1f}<extra></extra>'),
#               'legendgroup': '1, hadron',
#               'marker': {'color': '#EF553B', 'symbol': 'x'},
#               'mode': 'markers',
#               'name': '1, hadron',
#               'orientation': 'v',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'b75bc201-9738-4f1c-a89e-124b52a56e7d',
#               'x': {'bdata': ('AGCtRABgrUQAQK1EAECtRAAgrUQAIK' ... 'xEAICsRABgrEQAYKxEAGCsRABgrEQ='),
#                     'dtype': 'f4'},
#               'xaxis': 'x2',
#               'y': {'bdata': ('zfqhRTCCoUVgLqJFVZ2hRWXCoUWrrq' ... 'hFAoOnRczQqEUbIadFhkaoRbHEp0U='),
#                     'dtype': 'f4'},
#               'yaxis': 'y2'},
#              {'customdata': array([['hadron', '1'],
#                                    ['hadron', '1'],
#                                    ['hadron', '1'],
#                                    ['hadron', '1'],
#                                    ['hadron', '1'],
#                                    ['hadron', '1'],
#                                    ['hadron', '1'],
#                                    ['hadron', '1'],
#                                    ['hadron', '1'],
#                                    ['hadron', '1'],
#                                    ['hadron', '1'],
#                                    ['hadron', '1'],
#                                    ['hadron', '1'],
#                                    ['hadron', '1'],
#                                    ['hadron', '1'],
#                                    ['hadron', '1'],
#                                    ['hadron', '1'],
#                                    ['hadron', '1'],
#                                    ['hadron', '1'],
#                                    ['hadron', '1'],
#                                    ['hadron', '1'],
#                                    ['hadron', '1'],
#                                    ['hadron', '1'],
#                                    ['hadron', '1'],
#                                    ['hadron', '1']], dtype=object),
#               'hovertemplate': ('instance truth=%{customdata[1]' ... '>drift=%{y:.1f}<extra></extra>'),
#               'legendgroup': '1, hadron',
#               'marker': {'color': '#EF553B', 'symbol': 'x'},
#               'mode': 'markers',
#               'name': '1, hadron',
#               'orientation': 'v',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '1c7437c3-1ad1-4d21-bfd4-c3d87d3ffe33',
#               'x': {'bdata': ('AEDARAAgwEQAAMBEAOC/RADAv0QAoL' ... 'QAwL1EAKC9RACAvUQAYL1EAEC9RA=='),
#                     'dtype': 'f4'},
#               'xaxis': 'x3',
#               'y': {'bdata': ('ppuhRcPyoUXQPqJFrI2iRbXUokVWK6' ... 'UDyadFEBaoRXlwqEU1zqhFx9OoRQ=='),
#                     'dtype': 'f4'},
#               'yaxis': 'y3'}],
#     'layout': {'annotations': [{'showarrow': False,
#                                 'text': 'y',
#                                 'x': 0.15999999999999998,
#                                 'xanchor': 'center',
#                                 'xref': 'paper',
#                                 'y': 1.0,
#                                 'yanchor': 'bottom',
#                                 'yref': 'paper'},
#                                {'showarrow': False,
#                                 'text': 'v',
#                                 'x': 0.49999999999999994,
#                                 'xanchor': 'center',
#                                 'xref': 'paper',
#                                 'y': 1.0,
#                                 'yanchor': 'bottom',
#                                 'yref': 'paper'},
#                                {'showarrow': False,
#                                 'text': 'u',
#                                 'x': 0.8399999999999999,
#                                 'xanchor': 'center',
#                                 'xref': 'paper',
#                                 'y': 1.0,
#                                 'yanchor': 'bottom',
#                                 'yref': 'paper'}],
#                'legend': {'orientation': 'h',
#                           'title': {'text': 'instance truth, semantic truth'},
#                           'tracegroupgap': 0,
#                           'x': 1,
#                           'xanchor': 'right',
#                           'y': 1.05,
#                           'yanchor': 'bottom'},
#                'margin': {'b': 20, 'l': 20, 'r': 20, 't': 20},
#                'template': '...',
#                'title': {'automargin': True, 'text': 'True instance labels'},
#                'xaxis': {'anchor': 'y', 'domain': [0.0, 0.31999999999999995], 'title': {'text': 'proj'}},
#                'xaxis2': {'anchor': 'y2', 'domain': [0.33999999999999997, 0.6599999999999999], 'title': {'text': 'proj'}},
#                'xaxis3': {'anchor': 'y3', 'domain': [0.6799999999999999, 0.9999999999999999], 'title': {'text': 'proj'}},
#                'yaxis': {'anchor': 'x', 'domain': [0.0, 1.0], 'title': {'text': 'drift'}},
#                'yaxis2': {'anchor': 'x2', 'domain': [0.0, 1.0], 'matches': 'y', 'showticklabels': False},
#                'yaxis3': {'anchor': 'x3', 'domain': [0.0, 1.0], 'matches': 'y', 'showticklabels': False}}
# })
