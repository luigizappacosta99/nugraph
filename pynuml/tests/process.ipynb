# %% [markdown]
# ### Set autoreloading
# This extension will automatically update with any changes to packages in real time

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Import packages
# We'll need the `pynuml` and `nugraph` packages

# %%
import os
import nugraph as ng
import pynuml
import torch
import anywidget
# Out:
# /sps/lbno/zappacosta/miniconda3/envs/numl/lib/python3.13/site-packages/cupy/_environment.py:596: UserWarning:
#
#
# --------------------------------------------------------------------------------
#
#   CuPy may not function correctly because multiple CuPy packages are installed
#   in your environment:
#
#     cupy, cupy-cuda12x
#
#   Follow these steps to resolve this issue:
#
#     1. For all packages listed above, run the following command to remove all
#        existing CuPy installations:
#
#          $ pip uninstall <package_name>
#
#       If you previously installed CuPy via conda, also run the following:
#
#          $ conda uninstall cupy
#
#     2. Install the appropriate CuPy package.
#        Refer to the Installation Guide for detailed instructions.
#
#          https://docs.cupy.dev/en/stable/install.html
#
# --------------------------------------------------------------------------------

# %% [markdown]
# ### Open HDF5 event file
#
# This file contains the low-level tables we need to process into graph objects

# %%
#file = pynuml.io.File("/sps/lbno/zappacosta/v10_11/nugraph/pynuml/tests/MyFile_r20000001_s00000_ts653328.h5")
file = pynuml.io.File("/sps/lbno/zappacosta/v10_11/numl_outs/1kFiles_prova_r20000001_s00000_ts869004.h5")
# Out:
# Loading /sps/lbno/zappacosta/v10_11/numl_outs/1kFiles_prova_r20000001_s00000_ts869004.h5...

# %% [markdown]
# ### Create hit graph producer
#
# Create a class that can read input information and use it to generate graphs

# %%
semantic_labeller = pynuml.labels.StandardLabels()
event_labeller = pynuml.labels.FlavorLabels()
processor = pynuml.process.HitGraphProducer(
        file=file,
        semantic_labeller=semantic_labeller,
        event_labeller=event_labeller,
        label_vertex=False,
        label_position=False,
        lower_bound=20)

# %% [markdown]
# ## Configure plotting utility
# Instantiate the **pynuml** utility for plotting graph objects, which will allow us to visualise the graphs we create

# %%
plot = pynuml.plot.GraphPlot(
    planes=('u', 'v', 'y'),
    classes=semantic_labeller.labels[:-1])

# %% [markdown]
# ### Load a buffer of input graphs
#
# For interactive testing, we can use `read_data` to load the first 100 events in the event file using the following syntax, which will return a list of events that we can use to initialise an iterator

# %%
file.read_data(0,100,use_seq_cnt=False)
evts = file.build_evt()

# %% [markdown]
# ### Retrieve the next event
#
# This block retrieves an event from the buffer. Since we defined `evts` as an iterator over our 100 events, the following block can be executed multiple times, and each time it's executed, it will step to the next event in the buffer. After fetching an event, we pass it into the processor to create a graph. Not all events produce good graphs, so if the next event does not return a valid graph, the code will continue to fetch events until it finds the next event that produces a valid graph.

# %% [markdown]
# ### Visualise graph
#
# We can use the plotting utility to take a closer look at the graph we just produced.

# %%
name, data = processor(evts[20])
fig = plot.plot(data, target='instance', how='true', filter='show')
fig
# Out:
# FigureWidget({
#     'data': [{'customdata': array([['background', '-1'],
#                                    ['background', '-1'],
#                                    ['background', '-1'],
#                                    ...,
#                                    ['background', '-1'],
#                                    ['background', '-1'],
#                                    ['background', '-1']], shape=(470, 2), dtype=object),
#               'hovertemplate': ('instance truth=%{customdata[1]' ... '>drift=%{y:.1f}<extra></extra>'),
#               'legendgroup': '-1, background',
#               'marker': {'color': '#FF97FF', 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': '-1, background',
#               'showlegend': True,
#               'type': 'scattergl',
#               'uid': '8256e445-fe36-4dd0-a8c2-38cd0d21055b',
#               'x': {'bdata': ('AJANRQCgDUUAsA1FAIAORQCQDkUAsA' ... 'JFAKBTRQCwU0UAUFRFAGBURQCgVEU='),
#                     'dtype': 'f4'},
#               'xaxis': 'x',
#               'y': {'bdata': ('0hdwRZ0bcEWzGXBFpgdzRdQQc0VVCX' ... '5Ec8WpRLx9qURj0KVEinKlRHCIpEQ='),
#                     'dtype': 'f4'},
#               'yaxis': 'y'},
#              {'customdata': array([['background', '-1'],
#                                    ['background', '-1'],
#                                    ['background', '-1'],
#                                    ...,
#                                    ['background', '-1'],
#                                    ['background', '-1'],
#                                    ['background', '-1']], shape=(534, 2), dtype=object),
#               'hovertemplate': ('instance truth=%{customdata[1]' ... '>drift=%{y:.1f}<extra></extra>'),
#               'legendgroup': '-1, background',
#               'marker': {'color': '#FF97FF', 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': '-1, background',
#               'showlegend': False,
#               'type': 'scattergl',
#               'uid': '2692ce62-699d-46b7-be14-f2d32b953ebd',
#               'x': {'bdata': ('AADqRAAg6kQAIOpEAEDqRABA6kQA4M' ... 'A2RQCgNkUAIDdFADA3RQBAN0UAkDdF'),
#                     'dtype': 'f4'},
#               'xaxis': 'x2',
#               'y': {'bdata': ('lyRwRbAecEVADHNFaRtwRTUIc0V22h' ... 'ypRAy7qEQ8IqZELL6lRAOIpUQ1lqRE'),
#                     'dtype': 'f4'},
#               'yaxis': 'y2'},
#              {'customdata': array([['background', '-1'],
#                                    ['background', '-1'],
#                                    ['background', '-1'],
#                                    ...,
#                                    ['background', '-1'],
#                                    ['background', '-1'],
#                                    ['background', '-1']], shape=(727, 2), dtype=object),
#               'hovertemplate': ('instance truth=%{customdata[1]' ... '>drift=%{y:.1f}<extra></extra>'),
#               'legendgroup': '-1, background',
#               'marker': {'color': '#FF97FF', 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': '-1, background',
#               'showlegend': False,
#               'type': 'scattergl',
#               'uid': '0fd38d33-5857-4601-9d42-3476e66833f5',
#               'x': {'bdata': ('AODqRAAA60QAoO1EAMDtRAAA5EQAIO' ... 'UAYH1FAHB9RQCAfUUAoH1FALB9RQ=='),
#                     'dtype': 'f4'},
#               'xaxis': 'x3',
#               'y': {'bdata': ('0h5wRVcccEWCCHNFXgpzRXPZEkXu3R' ... 'SwQaZEYRSmRC/ApUSHd6VErm6lRA=='),
#                     'dtype': 'f4'},
#               'yaxis': 'y3'},
#              {'customdata': array([['diffuse', '-1'],
#                                    ['diffuse', '-1'],
#                                    ['diffuse', '-1'],
#                                    ['diffuse', '-1'],
#                                    ['diffuse', '-1'],
#                                    ['diffuse', '-1'],
#                                    ['diffuse', '-1']], dtype=object),
#               'hovertemplate': ('instance truth=%{customdata[1]' ... '>drift=%{y:.1f}<extra></extra>'),
#               'legendgroup': '-1, diffuse',
#               'marker': {'color': '#FF97FF', 'symbol': 'diamond'},
#               'mode': 'markers',
#               'name': '-1, diffuse',
#               'showlegend': True,
#               'type': 'scattergl',
#               'uid': 'f8a1a586-e88d-4b02-b369-12f8600ff677',
#               'x': {'bdata': 'AKAORQCgDkUAUCNFAFAjRQBgI0UAYCNFAIAjRQ==', 'dtype': 'f4'},
#               'xaxis': 'x',
#               'y': {'bdata': 'exRzRXsUc0V5Q0VFeUNFReBGRUXgRkVF5HpKRQ==', 'dtype': 'f4'},
#               'yaxis': 'y'},
#              {'customdata': array([['diffuse', '-1'],
#                                    ['diffuse', '-1'],
#                                    ['diffuse', '-1'],
#                                    ['diffuse', '-1'],
#                                    ['diffuse', '-1'],
#                                    ['diffuse', '-1'],
#                                    ['diffuse', '-1'],
#                                    ['diffuse', '-1']], dtype=object),
#               'hovertemplate': ('instance truth=%{customdata[1]' ... '>drift=%{y:.1f}<extra></extra>'),
#               'legendgroup': '-1, diffuse',
#               'marker': {'color': '#FF97FF', 'symbol': 'diamond'},
#               'mode': 'markers',
#               'name': '-1, diffuse',
#               'showlegend': False,
#               'type': 'scattergl',
#               'uid': '8cba16d4-1a94-49d8-98f7-314c7dd64e28',
#               'x': {'bdata': 'AODpRADg6UQAAOpEAADqRACg2UQAwNlEACDiRAAg4kQ=', 'dtype': 'f4'},
#               'xaxis': 'x2',
#               'y': {'bdata': 'ZRJzRWUSc0V8DnNFfA5zRQBwSkVjeUpFd3hFRXd4RUU=', 'dtype': 'f4'},
#               'yaxis': 'y2'},
#              {'customdata': array([['diffuse', '-1'],
#                                    ['diffuse', '-1'],
#                                    ['diffuse', '-1'],
#                                    ['diffuse', '-1'],
#                                    ['diffuse', '-1'],
#                                    ['diffuse', '-1']], dtype=object),
#               'hovertemplate': ('instance truth=%{customdata[1]' ... '>drift=%{y:.1f}<extra></extra>'),
#               'legendgroup': '-1, diffuse',
#               'marker': {'color': '#FF97FF', 'symbol': 'diamond'},
#               'mode': 'markers',
#               'name': '-1, diffuse',
#               'showlegend': False,
#               'type': 'scattergl',
#               'uid': '690ddb9d-c8e6-4c18-be42-8c0a19dd6b29',
#               'x': {'bdata': 'AIDtRACA7UQAAABFABAARQAgBkUAIAZF', 'dtype': 'f4'},
#               'xaxis': 'x3',
#               'y': {'bdata': 'JAxzRSQMc0XOcUpFuWpKRUQ8RUVEPEVF', 'dtype': 'f4'},
#               'yaxis': 'y3'},
#              {'customdata': array([['pion', '1'],
#                                    ['pion', '1'],
#                                    ['pion', '1'],
#                                    ['pion', '1'],
#                                    ['pion', '1'],
#                                    ['pion', '1'],
#                                    ['pion', '1'],
#                                    ['pion', '1'],
#                                    ['pion', '1'],
#                                    ['pion', '1'],
#                                    ['pion', '1'],
#                                    ['pion', '1'],
#                                    ['pion', '1'],
#                                    ['pion', '1'],
#                                    ['pion', '1'],
#                                    ['pion', '1'],
#                                    ['pion', '1'],
#                                    ['pion', '1'],
#                                    ['pion', '1'],
#                                    ['pion', '1'],
#                                    ['pion', '1'],
#                                    ['pion', '1'],
#                                    ['pion', '1'],
#                                    ['pion', '1'],
#                                    ['pion', '1'],
#                                    ['pion', '1'],
#                                    ['pion', '1'],
#                                    ['pion', '1'],
#                                    ['pion', '1'],
#                                    ['pion', '1'],
#                                    ['pion', '1'],
#                                    ['pion', '1'],
#                                    ['pion', '1'],
#                                    ['pion', '1'],
#                                    ['pion', '1'],
#                                    ['pion', '1'],
#                                    ['pion', '1'],
#                                    ['pion', '1'],
#                                    ['pion', '1'],
#                                    ['pion', '1']], dtype=object),
#               'hovertemplate': ('instance truth=%{customdata[1]' ... '>drift=%{y:.1f}<extra></extra>'),
#               'legendgroup': '1, pion',
#               'marker': {'color': '#FECB52', 'symbol': 'square'},
#               'mode': 'markers',
#               'name': '1, pion',
#               'showlegend': True,
#               'type': 'scattergl',
#               'uid': '6d812d05-3ec7-4fd8-9481-0c80d97de3a3',
#               'x': {'bdata': ('AAAeRQAAHkUAEB5FABAeRQAQHkUAEB' ... 'UAEB9FABAfRQAQH0UAIB9FACAfRQ=='),
#                     'dtype': 'f4'},
#               'xaxis': 'x',
#               'y': {'bdata': ('ewVYRXsFWEXMc1dFzHNXRcVLWEXFS1' ... 'UAUFFFTDhSRUw4UkV91lFFfdZRRQ=='),
#                     'dtype': 'f4'},
#               'yaxis': 'y'},
#              {'customdata': array([['pion', '1'],
#                                    ['pion', '1'],
#                                    ['pion', '1'],
#                                    ...,
#                                    ['pion', '1'],
#                                    ['pion', '1'],
#                                    ['pion', '1']], shape=(102, 2), dtype=object),
#               'hovertemplate': ('instance truth=%{customdata[1]' ... '>drift=%{y:.1f}<extra></extra>'),
#               'legendgroup': '1, pion',
#               'marker': {'color': '#FECB52', 'symbol': 'square'},
#               'mode': 'markers',
#               'name': '1, pion',
#               'showlegend': False,
#               'type': 'scattergl',
#               'uid': 'a1683929-e009-44e0-b653-efeadee5315a',
#               'x': {'bdata': ('AEDLRABAy0QAYMtEAGDLRACAy0QAgM' ... 'DSRAAA0kQAINJEACDSRABA0kQAQNJE'),
#                     'dtype': 'f4'},
#               'xaxis': 'x2',
#               'y': {'bdata': ('XExYRVxMWEWnDVhFpw1YRb+dV0W/nV' ... 'VQRTPFUEUkr1BFJK9QRRCPUEUQj1BF'),
#                     'dtype': 'f4'},
#               'yaxis': 'y2'},
#              {'customdata': array([['pion', '1'],
#                                    ['pion', '1'],
#                                    ['pion', '1'],
#                                    ...,
#                                    ['pion', '1'],
#                                    ['pion', '1'],
#                                    ['pion', '1']], shape=(200, 2), dtype=object),
#               'hovertemplate': ('instance truth=%{customdata[1]' ... '>drift=%{y:.1f}<extra></extra>'),
#               'legendgroup': '1, pion',
#               'marker': {'color': '#FECB52', 'symbol': 'square'},
#               'mode': 'markers',
#               'name': '1, pion',
#               'showlegend': False,
#               'type': 'scattergl',
#               'uid': '5dbeac70-4f2f-48b4-8881-7a9c9987894d',
#               'x': {'bdata': ('AODtRADg7UQAAO5EAADuRAAg7kQAIO' ... 'tEAED7RABg+0QAYPtEAID7RACA+0Q='),
#                     'dtype': 'f4'},
#               'xaxis': 'x3',
#               'y': {'bdata': ('dllYRXZZWEVIEVhFSBFYRUvCV0VLwl' ... 'BFDrJQRQOiUEUDolBFqJFQRaiRUEU='),
#                     'dtype': 'f4'},
#               'yaxis': 'y3'},
#              {'customdata': array([['michel', '2'],
#                                    ['michel', '2'],
#                                    ['michel', '2'],
#                                    ['michel', '2'],
#                                    ['michel', '2'],
#                                    ['michel', '2'],
#                                    ['michel', '2'],
#                                    ['michel', '2'],
#                                    ['michel', '2'],
#                                    ['michel', '2'],
#                                    ['michel', '2'],
#                                    ['michel', '2'],
#                                    ['michel', '2'],
#                                    ['michel', '2'],
#                                    ['michel', '2'],
#                                    ['michel', '2']], dtype=object),
#               'hovertemplate': ('instance truth=%{customdata[1]' ... '>drift=%{y:.1f}<extra></extra>'),
#               'legendgroup': '2, michel',
#               'marker': {'color': '#636efa', 'symbol': 'x'},
#               'mode': 'markers',
#               'name': '2, michel',
#               'showlegend': True,
#               'type': 'scattergl',
#               'uid': '6d369b6e-886a-407b-9521-1bf855a74b6c',
#               'x': {'bdata': ('ACAeRQAgHkUAIB5FACAeRQAgHkUAIB' ... 'UAMB5FADAeRQAwHkUAMB5FADAeRQ=='),
#                     'dtype': 'f4'},
#               'xaxis': 'x',
#               'y': {'bdata': ('fatXRX2rV0V9q1dFfatXRVZSWEVWUl' ... 'XDfFdF/SpYRf0qWEX9KlhF/SpYRQ=='),
#                     'dtype': 'f4'},
#               'yaxis': 'y'},
#              {'customdata': array([['michel', '2'],
#                                    ['michel', '2'],
#                                    ['michel', '2'],
#                                    ['michel', '2'],
#                                    ['michel', '2'],
#                                    ['michel', '2'],
#                                    ['michel', '2'],
#                                    ['michel', '2'],
#                                    ['michel', '2'],
#                                    ['michel', '2'],
#                                    ['michel', '2'],
#                                    ['michel', '2']], dtype=object),
#               'hovertemplate': ('instance truth=%{customdata[1]' ... '>drift=%{y:.1f}<extra></extra>'),
#               'legendgroup': '2, michel',
#               'marker': {'color': '#636efa', 'symbol': 'x'},
#               'mode': 'markers',
#               'name': '2, michel',
#               'showlegend': False,
#               'type': 'scattergl',
#               'uid': '0898963a-7a6f-4535-909d-3d88e1cf6582',
#               'x': {'bdata': 'AODKRADgykQA4MpEAODKRAAAy0QAAMtEAADLRAAAy0QAIMtEACDLRAAgy0QAIMtE', 'dtype': 'f4'},
#               'xaxis': 'x2',
#               'y': {'bdata': 'vr5XRb6+V0W+vldFvr5XRcAMWEXADFhFwAxYRcAMWEVxX1hFcV9YRXFfWEVxX1hF', 'dtype': 'f4'},
#               'yaxis': 'y2'},
#              {'customdata': array([['michel', '2'],
#                                    ['michel', '2'],
#                                    ['michel', '2'],
#                                    ['michel', '2'],
#                                    ['michel', '2'],
#                                    ['michel', '2'],
#                                    ['michel', '2'],
#                                    ['michel', '2']], dtype=object),
#               'hovertemplate': ('instance truth=%{customdata[1]' ... '>drift=%{y:.1f}<extra></extra>'),
#               'legendgroup': '2, michel',
#               'marker': {'color': '#636efa', 'symbol': 'x'},
#               'mode': 'markers',
#               'name': '2, michel',
#               'showlegend': False,
#               'type': 'scattergl',
#               'uid': '334cf54d-daac-4476-9c40-9df13c3ebe5d',
#               'x': {'bdata': 'AKDtRACg7UQAoO1EAKDtRADA7UQAwO1EAMDtRADA7UQ=', 'dtype': 'f4'},
#               'xaxis': 'x3',
#               'y': {'bdata': 'EbNXRRGzV0URs1dFEbNXRYJWWEWCVlhFglZYRYJWWEU=', 'dtype': 'f4'},
#               'yaxis': 'y3'},
#              {'customdata': array([['hadron', '5'],
#                                    ['hadron', '5'],
#                                    ['hadron', '5'],
#                                    ['hadron', '5'],
#                                    ['hadron', '5'],
#                                    ['hadron', '5'],
#                                    ['hadron', '5'],
#                                    ['hadron', '5'],
#                                    ['hadron', '5'],
#                                    ['hadron', '5'],
#                                    ['hadron', '5'],
#                                    ['hadron', '5'],
#                                    ['hadron', '5'],
#                                    ['hadron', '5'],
#                                    ['hadron', '5'],
#                                    ['hadron', '5'],
#                                    ['hadron', '5'],
#                                    ['hadron', '5'],
#                                    ['hadron', '5'],
#                                    ['hadron', '5']], dtype=object),
#               'hovertemplate': ('instance truth=%{customdata[1]' ... '>drift=%{y:.1f}<extra></extra>'),
#               'legendgroup': '5, hadron',
#               'marker': {'color': '#EF553B', 'symbol': 'cross'},
#               'mode': 'markers',
#               'name': '5, hadron',
#               'showlegend': True,
#               'type': 'scattergl',
#               'uid': 'bdaf643c-9d9c-43c5-b568-ffdfe15e56c4',
#               'x': {'bdata': ('ABAfRQAgH0UAMB9FAEAfRQBQH0UAYB' ... 'BFABAgRQAgIEUAUCNFAGAjRQBwI0U='),
#                     'dtype': 'f4'},
#               'xaxis': 'x',
#               'y': {'bdata': ('AHBQRfN4UEW/EFBFV9tPRUyQT0UAKE' ... 'tFI4JLRSJqS0UJJ0tFgQtLRYuxSkU='),
#                     'dtype': 'f4'},
#               'yaxis': 'y'},
#              {'customdata': array([['hadron', '5'],
#                                    ['hadron', '5'],
#                                    ['hadron', '5'],
#                                    ['hadron', '5'],
#                                    ['hadron', '5'],
#                                    ['hadron', '5'],
#                                    ['hadron', '5'],
#                                    ['hadron', '5']], dtype=object),
#               'hovertemplate': ('instance truth=%{customdata[1]' ... '>drift=%{y:.1f}<extra></extra>'),
#               'legendgroup': '5, hadron',
#               'marker': {'color': '#EF553B', 'symbol': 'cross'},
#               'mode': 'markers',
#               'name': '5, hadron',
#               'showlegend': False,
#               'type': 'scattergl',
#               'uid': '1768122f-3de5-4583-b598-788de53e0eff',
#               'x': {'bdata': 'AGDSRACA0kQAoNJEAMDSRADg0kQAANNEAIDZRACg2UQ=', 'dtype': 'f4'},
#               'xaxis': 'x2',
#               'y': {'bdata': 'ZG9QRQAoUEXUgk5FT2tNRZ9VTEX2zktF09pKRQBgS0U=', 'dtype': 'f4'},
#               'yaxis': 'y2'},
#              {'customdata': array([['hadron', '5'],
#                                    ['hadron', '5'],
#                                    ['hadron', '5'],
#                                    ['hadron', '5'],
#                                    ['hadron', '5'],
#                                    ['hadron', '5'],
#                                    ['hadron', '5'],
#                                    ['hadron', '5'],
#                                    ['hadron', '5'],
#                                    ['hadron', '5'],
#                                    ['hadron', '5'],
#                                    ['hadron', '5'],
#                                    ['hadron', '5'],
#                                    ['hadron', '5'],
#                                    ['hadron', '5'],
#                                    ['hadron', '5'],
#                                    ['hadron', '5'],
#                                    ['hadron', '5'],
#                                    ['hadron', '5'],
#                                    ['hadron', '5'],
#                                    ['hadron', '5'],
#                                    ['hadron', '5'],
#                                    ['hadron', '5'],
#                                    ['hadron', '5'],
#                                    ['hadron', '5'],
#                                    ['hadron', '5'],
#                                    ['hadron', '5'],
#                                    ['hadron', '5'],
#                                    ['hadron', '5'],
#                                    ['hadron', '5'],
#                                    ['hadron', '5'],
#                                    ['hadron', '5'],
#                                    ['hadron', '5'],
#                                    ['hadron', '5'],
#                                    ['hadron', '5']], dtype=object),
#               'hovertemplate': ('instance truth=%{customdata[1]' ... '>drift=%{y:.1f}<extra></extra>'),
#               'legendgroup': '5, hadron',
#               'marker': {'color': '#EF553B', 'symbol': 'cross'},
#               'mode': 'markers',
#               'name': '5, hadron',
#               'showlegend': False,
#               'type': 'scattergl',
#               'uid': '569b4c6a-42c2-4023-9b6a-35a4ac90613b',
#               'x': {'bdata': ('AKD7RADA+0QA4PtEAAD8RAAg/EQAQP' ... '9EAGD/RACA/0QAoP9EAMD/RADg/0Q='),
#                     'dtype': 'f4'},
#               'xaxis': 'x3',
#               'y': {'bdata': ('OYFQRaFuUEU1a1BFL2tQRVAaUEWAxk' ... 'tF12lLRcYzS0UwAUtFCs9KRbudSkU='),
#                     'dtype': 'f4'},
#               'yaxis': 'y3'},
#              {'customdata': array([['hadron', '3'],
#                                    ['hadron', '3'],
#                                    ['hadron', '3'],
#                                    ['hadron', '3'],
#                                    ['hadron', '3'],
#                                    ['hadron', '3'],
#                                    ['hadron', '3'],
#                                    ['hadron', '3'],
#                                    ['hadron', '3'],
#                                    ['hadron', '3'],
#                                    ['hadron', '3'],
#                                    ['hadron', '3'],
#                                    ['hadron', '3'],
#                                    ['hadron', '3'],
#                                    ['hadron', '3'],
#                                    ['hadron', '3'],
#                                    ['hadron', '3'],
#                                    ['hadron', '3'],
#                                    ['hadron', '3'],
#                                    ['hadron', '3'],
#                                    ['hadron', '3'],
#                                    ['hadron', '3'],
#                                    ['hadron', '3'],
#                                    ['hadron', '3'],
#                                    ['hadron', '3'],
#                                    ['hadron', '3'],
#                                    ['hadron', '3'],
#                                    ['hadron', '3'],
#                                    ['hadron', '3'],
#                                    ['hadron', '3'],
#                                    ['hadron', '3'],
#                                    ['hadron', '3'],
#                                    ['hadron', '3'],
#                                    ['hadron', '3'],
#                                    ['hadron', '3'],
#                                    ['hadron', '3']], dtype=object),
#               'hovertemplate': ('instance truth=%{customdata[1]' ... '>drift=%{y:.1f}<extra></extra>'),
#               'legendgroup': '3, hadron',
#               'marker': {'color': '#00cc96', 'symbol': 'cross'},
#               'mode': 'markers',
#               'name': '3, hadron',
#               'showlegend': True,
#               'type': 'scattergl',
#               'uid': 'ff04d9f5-3ff6-44f1-949b-bfad41ae07b0',
#               'x': {'bdata': ('ADAfRQAwH0UAQB9FAEAfRQCAH0UAgB' ... 'AjRQBwI0UAgCNFAIAjRQCQI0UAkCNF'),
#                     'dtype': 'f4'},
#               'xaxis': 'x',
#               'y': {'bdata': ('adxQRWncUEXCHVFFwh1RRfhuUkX4bl' ... 'ZVRfimVUUM2lVFDNpVRWzuVUVs7lVF'),
#                     'dtype': 'f4'},
#               'yaxis': 'y'},
#              {'customdata': array([['hadron', '3'],
#                                    ['hadron', '3'],
#                                    ['hadron', '3'],
#                                    ['hadron', '3'],
#                                    ['hadron', '3'],
#                                    ['hadron', '3'],
#                                    ['hadron', '3'],
#                                    ['hadron', '3'],
#                                    ['hadron', '3'],
#                                    ['hadron', '3'],
#                                    ['hadron', '3'],
#                                    ['hadron', '3'],
#                                    ['hadron', '3'],
#                                    ['hadron', '3']], dtype=object),
#               'hovertemplate': ('instance truth=%{customdata[1]' ... '>drift=%{y:.1f}<extra></extra>'),
#               'legendgroup': '3, hadron',
#               'marker': {'color': '#00cc96', 'symbol': 'cross'},
#               'mode': 'markers',
#               'name': '3, hadron',
#               'showlegend': False,
#               'type': 'scattergl',
#               'uid': '6cbed3b8-b3b3-4fb5-89a6-a601e62b2a00',
#               'x': {'bdata': 'AKDSRACg0kQAwNJEAMDSRADg0kQA4NJEAADTRAAA00QAgNlEAIDZRACg2UQAoNlEAMDZRADA2UQ=',
#                     'dtype': 'f4'},
#               'xaxis': 'x2',
#               'y': {'bdata': 'WPVRRVj1UUUvelNFL3pTRVtZVEVbWVRF+LJURfiyVEWejlVFno5VRTi4VUU4uFVFXs9VRV7PVUU=',
#                     'dtype': 'f4'},
#               'yaxis': 'y2'},
#              {'customdata': array([['hadron', '3'],
#                                    ['hadron', '3'],
#                                    ['hadron', '3'],
#                                    ['hadron', '3'],
#                                    ['hadron', '3'],
#                                    ['hadron', '3'],
#                                    ['hadron', '3'],
#                                    ['hadron', '3'],
#                                    ['hadron', '3'],
#                                    ['hadron', '3'],
#                                    ['hadron', '3'],
#                                    ['hadron', '3'],
#                                    ['hadron', '3'],
#                                    ['hadron', '3'],
#                                    ['hadron', '3'],
#                                    ['hadron', '3'],
#                                    ['hadron', '3'],
#                                    ['hadron', '3'],
#                                    ['hadron', '3'],
#                                    ['hadron', '3'],
#                                    ['hadron', '3'],
#                                    ['hadron', '3'],
#                                    ['hadron', '3'],
#                                    ['hadron', '3'],
#                                    ['hadron', '3'],
#                                    ['hadron', '3'],
#                                    ['hadron', '3'],
#                                    ['hadron', '3'],
#                                    ['hadron', '3'],
#                                    ['hadron', '3'],
#                                    ['hadron', '3'],
#                                    ['hadron', '3'],
#                                    ['hadron', '3'],
#                                    ['hadron', '3'],
#                                    ['hadron', '3'],
#                                    ['hadron', '3'],
#                                    ['hadron', '3'],
#                                    ['hadron', '3'],
#                                    ['hadron', '3'],
#                                    ['hadron', '3'],
#                                    ['hadron', '3'],
#                                    ['hadron', '3'],
#                                    ['hadron', '3'],
#                                    ['hadron', '3'],
#                                    ['hadron', '3'],
#                                    ['hadron', '3'],
#                                    ['hadron', '3'],
#                                    ['hadron', '3'],
#                                    ['hadron', '3'],
#                                    ['hadron', '3'],
#                                    ['hadron', '3'],
#                                    ['hadron', '3'],
#                                    ['hadron', '3'],
#                                    ['hadron', '3'],
#                                    ['hadron', '3'],
#                                    ['hadron', '3'],
#                                    ['hadron', '3'],
#                                    ['hadron', '3']], dtype=object),
#               'hovertemplate': ('instance truth=%{customdata[1]' ... '>drift=%{y:.1f}<extra></extra>'),
#               'legendgroup': '3, hadron',
#               'marker': {'color': '#00cc96', 'symbol': 'cross'},
#               'mode': 'markers',
#               'name': '3, hadron',
#               'showlegend': False,
#               'type': 'scattergl',
#               'uid': 'a8583c5d-6f6b-43f3-bc21-5e4b817038e3',
#               'x': {'bdata': ('ACD8RAAg/EQAwPxEAMD8RADg/EQA4P' ... 'QA4P9EAAAARQAAAEUAEABFABAARQ=='),
#                     'dtype': 'f4'},
#               'xaxis': 'x3',
#               'y': {'bdata': ('A8RQRQPEUEVphVFFaYVRRamzUUWps1' ... 'Xiv1VFb+RVRW/kVUVDAFZFQwBWRQ=='),
#                     'dtype': 'f4'},
#               'yaxis': 'y3'},
#              {'customdata': array([['pion', '0'],
#                                    ['pion', '0'],
#                                    ['pion', '0'],
#                                    ['pion', '0'],
#                                    ['pion', '0'],
#                                    ['pion', '0'],
#                                    ['pion', '0'],
#                                    ['pion', '0'],
#                                    ['pion', '0'],
#                                    ['pion', '0']], dtype=object),
#               'hovertemplate': ('instance truth=%{customdata[1]' ... '>drift=%{y:.1f}<extra></extra>'),
#               'legendgroup': '0, pion',
#               'marker': {'color': '#ab63fa', 'symbol': 'square'},
#               'mode': 'markers',
#               'name': '0, pion',
#               'showlegend': True,
#               'type': 'scattergl',
#               'uid': '1d02c1c9-cdce-4865-88bb-c0a51be8a3c4',
#               'x': {'bdata': 'AFAfRQBQH0UAYB9FAGAfRQBwH0UAcB9FABAjRQAQI0UAICNFACAjRQ==', 'dtype': 'f4'},
#               'xaxis': 'x',
#               'y': {'bdata': '7WtRRe1rUUXEtlFFxLZRRScgUkUnIFJF9IZURfSGVEWJgFRFiYBURQ==', 'dtype': 'f4'},
#               'yaxis': 'y'},
#              {'customdata': array([['pion', '0'],
#                                    ['pion', '0'],
#                                    ['pion', '0'],
#                                    ['pion', '0'],
#                                    ['pion', '0'],
#                                    ['pion', '0'],
#                                    ['pion', '0'],
#                                    ['pion', '0'],
#                                    ['pion', '0'],
#                                    ['pion', '0'],
#                                    ['pion', '0'],
#                                    ['pion', '0'],
#                                    ['pion', '0'],
#                                    ['pion', '0'],
#                                    ['pion', '0'],
#                                    ['pion', '0'],
#                                    ['pion', '0'],
#                                    ['pion', '0'],
#                                    ['pion', '0'],
#                                    ['pion', '0']], dtype=object),
#               'hovertemplate': ('instance truth=%{customdata[1]' ... '>drift=%{y:.1f}<extra></extra>'),
#               'legendgroup': '0, pion',
#               'marker': {'color': '#ab63fa', 'symbol': 'square'},
#               'mode': 'markers',
#               'name': '0, pion',
#               'showlegend': False,
#               'type': 'scattergl',
#               'uid': '8e0ecfdb-6442-4c3a-9fab-e856ad68e9ec',
#               'x': {'bdata': ('AKDSRACg0kQAwNJEAMDSRADg0kQA4N' ... 'NEAIDTRAAA2kQAANpEACDaRAAg2kQ='),
#                     'dtype': 'f4'},
#               'xaxis': 'x2',
#               'y': {'bdata': ('eBBRRXgQUUXlaFFF5WhRRcrEUUXKxF' ... 'RFcTBURbR4VEW0eFRFJ3xURSd8VEU='),
#                     'dtype': 'f4'},
#               'yaxis': 'y2'},
#              {'customdata': array([['pion', '0'],
#                                    ['pion', '0'],
#                                    ['pion', '0'],
#                                    ['pion', '0'],
#                                    ['pion', '0'],
#                                    ['pion', '0'],
#                                    ['pion', '0'],
#                                    ['pion', '0'],
#                                    ['pion', '0'],
#                                    ['pion', '0'],
#                                    ['pion', '0'],
#                                    ['pion', '0'],
#                                    ['pion', '0'],
#                                    ['pion', '0'],
#                                    ['pion', '0'],
#                                    ['pion', '0'],
#                                    ['pion', '0'],
#                                    ['pion', '0'],
#                                    ['pion', '0'],
#                                    ['pion', '0'],
#                                    ['pion', '0'],
#                                    ['pion', '0'],
#                                    ['pion', '0'],
#                                    ['pion', '0'],
#                                    ['pion', '0'],
#                                    ['pion', '0'],
#                                    ['pion', '0'],
#                                    ['pion', '0'],
#                                    ['pion', '0'],
#                                    ['pion', '0'],
#                                    ['pion', '0'],
#                                    ['pion', '0']], dtype=object),
#               'hovertemplate': ('instance truth=%{customdata[1]' ... '>drift=%{y:.1f}<extra></extra>'),
#               'legendgroup': '0, pion',
#               'marker': {'color': '#ab63fa', 'symbol': 'square'},
#               'mode': 'markers',
#               'name': '0, pion',
#               'showlegend': False,
#               'type': 'scattergl',
#               'uid': '1f81fa81-d876-4f1a-a3f5-32d1596de733',
#               'x': {'bdata': ('AED8RABA/EQAYPxEAGD8RACA/EQAgP' ... '9EAED/RABg/0QAYP9EAID/RACA/0Q='),
#                     'dtype': 'f4'},
#               'xaxis': 'x3',
#               'y': {'bdata': ('XuZQRV7mUEVnClFFZwpRRQ0uUUUNLl' ... 'RFtzdURdlbVEXZW1RFqX1URal9VEU='),
#                     'dtype': 'f4'},
#               'yaxis': 'y3'},
#              {'customdata': array([['muon', '4'],
#                                    ['muon', '4'],
#                                    ['muon', '4'],
#                                    ...,
#                                    ['muon', '4'],
#                                    ['muon', '4'],
#                                    ['muon', '4']], shape=(950, 2), dtype=object),
#               'hovertemplate': ('instance truth=%{customdata[1]' ... '>drift=%{y:.1f}<extra></extra>'),
#               'legendgroup': '4, muon',
#               'marker': {'color': '#FFA15A', 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': '4, muon',
#               'showlegend': True,
#               'type': 'scattergl',
#               'uid': '37f5d8e9-c92b-4d54-b780-a01cec9a5ed2',
#               'x': {'bdata': ('AHAfRQBwH0UAgB9FAIAfRQCQH0UAkB' ... 'RFAHBURQCAVEUAgFRFAJBURQCQVEU='),
#                     'dtype': 'f4'},
#               'xaxis': 'x',
#               'y': {'bdata': ('ALBORQCwTkV3Nk9FdzZPRaoCT0WqAk' ... 'VE7S6lRBHSpEQR0qREuaWkRLmlpEQ='),
#                     'dtype': 'f4'},
#               'yaxis': 'y'},
#              {'customdata': array([['muon', '4'],
#                                    ['muon', '4'],
#                                    ['muon', '4'],
#                                    ...,
#                                    ['muon', '4'],
#                                    ['muon', '4'],
#                                    ['muon', '4']], shape=(1254, 2), dtype=object),
#               'hovertemplate': ('instance truth=%{customdata[1]' ... '>drift=%{y:.1f}<extra></extra>'),
#               'legendgroup': '4, muon',
#               'marker': {'color': '#FFA15A', 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': '4, muon',
#               'showlegend': False,
#               'type': 'scattergl',
#               'uid': '4af89d4d-1390-43b5-bf66-28eb612e0647',
#               'x': {'bdata': ('AKDSRACg0kQAwNJEAMDSRADg0kQA4N' ... 'A3RQBgN0UAcDdFAHA3RQCAN0UAgDdF'),
#                     'dtype': 'f4'},
#               'xaxis': 'x2',
#               'y': {'bdata': ('5TlQReU5UEWRFFBFkRRQRUPwT0VD8E' ... 'WlRPoFpUQ8waREPMGkRECbpERAm6RE'),
#                     'dtype': 'f4'},
#               'yaxis': 'y2'},
#              {'customdata': array([['muon', '4'],
#                                    ['muon', '4'],
#                                    ['muon', '4'],
#                                    ...,
#                                    ['muon', '4'],
#                                    ['muon', '4'],
#                                    ['muon', '4']], shape=(3374, 2), dtype=object),
#               'hovertemplate': ('instance truth=%{customdata[1]' ... '>drift=%{y:.1f}<extra></extra>'),
#               'legendgroup': '4, muon',
#               'marker': {'color': '#FFA15A', 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': '4, muon',
#               'showlegend': False,
#               'type': 'scattergl',
#               'uid': 'c1944dab-2943-4cef-af21-f493d2c792b1',
#               'x': {'bdata': ('AED8RABA/EQAYPxEAGD8RADA/EQAwP' ... '5FAEB+RQBQfkUAUH5FAGB+RQBgfkU='),
#                     'dtype': 'f4'},
#               'xaxis': 'x3',
#               'y': {'bdata': ('8DZQRfA2UEX8NFBF/DRQRaD7T0Wg+0' ... 'REx6OkRJCQpESQkKREj3mkRI95pEQ='),
#                     'dtype': 'f4'},
#               'yaxis': 'y3'},
#              {'customdata': array([['hadron', '6']], dtype=object),
#               'hovertemplate': ('instance truth=%{customdata[1]' ... '>drift=%{y:.1f}<extra></extra>'),
#               'legendgroup': '6, hadron',
#               'marker': {'color': '#19d3f3', 'symbol': 'cross'},
#               'mode': 'markers',
#               'name': '6, hadron',
#               'showlegend': True,
#               'type': 'scattergl',
#               'uid': '64aabb23-0915-4e7a-9d0f-58366b5d1408',
#               'x': {'bdata': 'AJAjRQ==', 'dtype': 'f4'},
#               'xaxis': 'x',
#               'y': {'bdata': 'jHZKRQ==', 'dtype': 'f4'},
#               'yaxis': 'y'},
#              {'customdata': array([['hadron', '6']], dtype=object),
#               'hovertemplate': ('instance truth=%{customdata[1]' ... '>drift=%{y:.1f}<extra></extra>'),
#               'legendgroup': '6, hadron',
#               'marker': {'color': '#19d3f3', 'symbol': 'cross'},
#               'mode': 'markers',
#               'name': '6, hadron',
#               'showlegend': False,
#               'type': 'scattergl',
#               'uid': '0219a795-0182-4c46-92c5-7247890d8ff8',
#               'x': {'bdata': 'AODZRA==', 'dtype': 'f4'},
#               'xaxis': 'x2',
#               'y': {'bdata': 'KXdKRQ==', 'dtype': 'f4'},
#               'yaxis': 'y2'},
#              {'customdata': array([['hadron', '6'],
#                                    ['hadron', '6'],
#                                    ['hadron', '6']], dtype=object),
#               'hovertemplate': ('instance truth=%{customdata[1]' ... '>drift=%{y:.1f}<extra></extra>'),
#               'legendgroup': '6, hadron',
#               'marker': {'color': '#19d3f3', 'symbol': 'cross'},
#               'mode': 'markers',
#               'name': '6, hadron',
#               'showlegend': False,
#               'type': 'scattergl',
#               'uid': '2a4b0531-356e-4dbe-a8d2-aa5ebcaa868f',
#               'x': {'bdata': 'ACAARQAwAEUAQABF', 'dtype': 'f4'},
#               'xaxis': 'x3',
#               'y': {'bdata': 'R3FKRaV5SkUKgUpF', 'dtype': 'f4'},
#               'yaxis': 'y3'}],
#     'layout': {'annotations': [{'showarrow': False,
#                                 'text': 'u',
#                                 'x': 0.15999999999999998,
#                                 'xanchor': 'center',
#                                 'xref': 'paper',
#                                 'y': 1.0,
#                                 'yanchor': 'bottom',
#                                 'yref': 'paper'},
#                                {'showarrow': False,
#                                 'text': 'v',
#                                 'x': 0.49999999999999994,
#                                 'xanchor': 'center',
#                                 'xref': 'paper',
#                                 'y': 1.0,
#                                 'yanchor': 'bottom',
#                                 'yref': 'paper'},
#                                {'showarrow': False,
#                                 'text': 'y',
#                                 'x': 0.8399999999999999,
#                                 'xanchor': 'center',
#                                 'xref': 'paper',
#                                 'y': 1.0,
#                                 'yanchor': 'bottom',
#                                 'yref': 'paper'}],
#                'legend': {'orientation': 'h',
#                           'title': {'text': 'instance truth, semantic truth'},
#                           'tracegroupgap': 0,
#                           'x': 1,
#                           'xanchor': 'right',
#                           'y': 1.05,
#                           'yanchor': 'bottom'},
#                'margin': {'b': 20, 'l': 20, 'r': 20, 't': 20},
#                'template': '...',
#                'title': {'automargin': True, 'text': 'True instance labels'},
#                'xaxis': {'anchor': 'y', 'domain': [0.0, 0.31999999999999995], 'title': {'text': 'proj'}},
#                'xaxis2': {'anchor': 'y2', 'domain': [0.33999999999999997, 0.6599999999999999], 'title': {'text': 'proj'}},
#                'xaxis3': {'anchor': 'y3', 'domain': [0.6799999999999999, 0.9999999999999999], 'title': {'text': 'proj'}},
#                'yaxis': {'anchor': 'x', 'domain': [0.0, 1.0], 'title': {'text': 'drift'}},
#                'yaxis2': {'anchor': 'x2', 'domain': [0.0, 1.0], 'matches': 'y', 'showticklabels': False},
#                'yaxis3': {'anchor': 'x3', 'domain': [0.0, 1.0], 'matches': 'y', 'showticklabels': False}}
# })

# %%
2657-2762
# Out:
# -105
