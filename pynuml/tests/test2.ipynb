# %%
import file as FILE

# %%
f = FILE.MyFile("/sps/lbno/zappacosta/v10_11/nugraph/pynuml/tests/NewDariaFile_r20000014_s00000_ts377103.h5")
# Out:
# Loading /sps/lbno/zappacosta/v10_11/nugraph/pynuml/tests/NewDariaFile_r20000014_s00000_ts377103.h5...
# 10

# %%
f.read_data_all(use_seq_cnt=False, evt_part=0)
evts = f.build_evt()
# Out:
# data_partition
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 f.read_data_all(use_seq_cnt=False, evt_part=0)
# ----> 2 evts = f.build_evt()
#
# File /sps/lbno/zappacosta/v10_11/nugraph/pynuml/tests/file.py:664, in MyFile.build_evt(self, start, count)
#     655 def build_evt(self,
#     656               start: int = None,
#     657               count: int = None) -> List[Dict]:
#    (...)    661     # self._cnt_name into a python list containing Pandas DataFrames, one
#     662     # for a unique event ID.
#     663     if not self._groups:
# --> 664         raise Exception('cannot build event without adding any HDF5 groups')
#     666     ret_list = []
#     668     if start is None: start = self._my_start
#
# Exception: cannot build event without adding any HDF5 groups

# %%
f.keys()
# Out:
# <KeysViewHDF5 ['edep_table', 'event_table', 'hit_table', 'particle_table', 'spacepoint_table']>

# %%
f.read_seq()
